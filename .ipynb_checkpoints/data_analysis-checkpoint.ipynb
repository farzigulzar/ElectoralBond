# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import panel as pn

pn.extension()

pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4b58d8d5-b3cb-45f6-9aae-44df9b4fc554'>
#   <div id="e3fa9f73-4d02-4299-9ebc-415d9fdfde1e" data-root-id="4b58d8d5-b3cb-45f6-9aae-44df9b4fc554" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"57c13ae5-3203-4c4d-8f73-49a464a38e45":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4b58d8d5-b3cb-45f6-9aae-44df9b4fc554"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"15ea34e9-3194-43a4-a944-7d70eb3f36ee","attributes":{"plot_id":"4b58d8d5-b3cb-45f6-9aae-44df9b4fc554","comm_id":"2a1180fc10624ec991596897751ee02c","client_comm_id":"c60287b8dace41f5a879614705309cc6"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"57c13ae5-3203-4c4d-8f73-49a464a38e45","roots":{"4b58d8d5-b3cb-45f6-9aae-44df9b4fc554":"e3fa9f73-4d02-4299-9ebc-415d9fdfde1e"},"root_ids":["4b58d8d5-b3cb-45f6-9aae-44df9b4fc554"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
filepath = 'Cleaned_merged_data\electoral.csv'
df = pd.read_csv(filepath)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\Akash\AppData\Local\Temp\ipykernel_19432\1846034037.py:1: SyntaxWarning: invalid escape sequence '\e'
#   filepath = 'Cleaned_merged_data\electoral.csv'

# %%
df.head()
# Out:
#    Sr No_donor  Reference No (URN) Journal Date Date of Purchase  \
# 0       8985.0        8.472022e+20   2022-04-08       2022-04-08
# 1       5806.0        3.002021e+20   2021-10-07       2021-10-07
# 2       5775.0        3.002021e+20   2021-10-07       2021-10-07
# 3       5808.0        3.002021e+20   2021-10-07       2021-10-07
# 4       5774.0        3.002021e+20   2021-10-07       2021-10-07
#
#   Date of Expiry              Name of the Purchaser  Denominations  \
# 0     2022-04-22  KOYA AND COMPANY CONSTRUCTION LTD     10000000.0
# 1     2021-10-21              K RAHEJA CORP PVT LTD     10000000.0
# 2     2021-10-21                CAPSTAN TRADING LLP     10000000.0
# 3     2021-10-21              K RAHEJA CORP PVT LTD     10000000.0
# 4     2021-10-21                CAPSTAN TRADING LLP     10000000.0
#
#    Issue Branch Code  Issue Teller Status Prefix Bond Number  Sr No_reciever  \
# 0              847.0     3898296.0   Paid            OC10000         10376.0
# 1              300.0     7905165.0   Paid            OC10001          7043.0
# 2              300.0     7905165.0   Paid            OC10002          7066.0
# 3              300.0     7905165.0   Paid            OC10003          7045.0
# 4              300.0     7905165.0   Paid            OC10004          7065.0
#
#   Date of Encashment Name of the Political Party  \
# 0         2022-04-12      BHARAT RASHTRA SAMITHI
# 1         2021-10-08      BHARAT RASHTRA SAMITHI
# 2         2021-10-08      BHARAT RASHTRA SAMITHI
# 3         2021-10-08      BHARAT RASHTRA SAMITHI
# 4         2021-10-08      BHARAT RASHTRA SAMITHI
#
#   Account no. of Political Party  Pay Branch Code  Pay Teller
# 0                    *******7477            847.0   3898296.0
# 1                    *******7477            847.0   6417329.0
# 2                    *******7477            847.0   6417329.0
# 3                    *******7477            847.0   6417329.0
# 4                    *******7477            847.0   6417329.0

# %%
df['Name of the Political Party'].value_counts()
# Out:
# Name of the Political Party
# BHARATIYA JANATA PARTY                                        8633
# ALL INDIA TRINAMOOL CONGRESS                                  3305
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE                       3146
# BHARAT RASHTRA SAMITHI                                        1806
# BIJU JANATA DAL                                                861
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                648
# YSR CONGRESS PARTY (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)     472
# SHIVSENA                                                       355
# TELUGU DESAM PARTY                                             279
# AAM AADMI PARTY                                                245
# RASHTRIYA JANTA DAL                                            150
# NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH                 121
# JANATA DAL ( SECULAR )                                          75
# SIKKIM KRANTIKARI MORCHA                                        50
# ADYAKSHA SAMAJVADI PARTY                                        46
# JHARKHAND MUKTI MORCHA                                          45
# JANASENA PARTY                                                  39
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                        38
# SHIROMANI AKALI DAL                                             33
# MAHARASHTRAWADI GOMNTAK PARTY                                   28
# GOA FORWARD PARTY                                               17
# BIHAR PRADESH JANTA DAL(UNITED)                                 14
# SIKKIM DEMOCRATIC FRONT                                         10
# JAMMU AND KASHMIR NATIONAL CONFERENCE                            5
# Name: count, dtype: int64

# %%
denom_ = df[['Name of the Political Party', 'Denominations']].groupby('Name of the Political Party').sum().sort_values(by='Denominations',ascending=False)
denom_['Percentage'] = (100*denom_['Denominations']/denom_['Denominations'].sum())
denom_
# Out:
#                                                     Denominations  Percentage
# Name of the Political Party
# BHARATIYA JANATA PARTY                               6.060511e+10   47.462360
# ALL INDIA TRINAMOOL CONGRESS                         1.609531e+10   12.604904
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE              1.421866e+10   11.135215
# BHARAT RASHTRA SAMITHI                               1.214710e+10    9.512894
# BIJU JANATA DAL                                      7.755000e+09    6.073260
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                      6.390000e+09    5.004272
# YSR CONGRESS PARTY (YUVAJANA SRAMIKA RYTHU CONG...   3.370000e+09    2.639186
# TELUGU DESAM PARTY                                   2.188800e+09    1.714139
# SHIVSENA                                             1.593814e+09    1.248181
# RASHTRIYA JANTA DAL                                  7.350000e+08    0.575609
# AAM AADMI PARTY                                      6.545000e+08    0.512566
# JANATA DAL ( SECULAR )                               4.350000e+08    0.340666
# SIKKIM KRANTIKARI MORCHA                             3.650000e+08    0.285847
# NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH       3.100000e+08    0.242774
# JANASENA PARTY                                       2.100000e+08    0.164460
# ADYAKSHA SAMAJVADI PARTY                             1.405000e+08    0.110031
# BIHAR PRADESH JANTA DAL(UNITED)                      1.400000e+08    0.109640
# JHARKHAND MUKTI MORCHA                               1.350000e+08    0.105724
# SHIROMANI AKALI DAL                                  7.260000e+07    0.056856
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM             6.050000e+07    0.047380
# SIKKIM DEMOCRATIC FRONT                              5.500000e+07    0.043073
# MAHARASHTRAWADI GOMNTAK PARTY                        5.500000e+06    0.004307
# JAMMU AND KASHMIR NATIONAL CONFERENCE                5.000000e+06    0.003916
# GOA FORWARD PARTY                                    3.500000e+06    0.002741

# %%
# plot
fig, ax =plt.subplots()
ax.pie(denom_['Denominations'], labels= denom_.index, autopct='%1.2f%%')
ax.legend(loc='upper left',bbox_to_anchor=(2.1, 1))
plt.show() 
# top line

# %%
# for a particular party, show all the donors
    #  for a particular party, show all the donations provided across the time period (with a stacked bar chart involving the donors as stacks)
party = 'BHARATIYA JANATA PARTY'

df[(df['Name of the Political Party']==party) & (df['Name of the Purchaser'].isnull())]['Denominations'].sum()
# df['Name of the Political Party']==party) & (df['Issue Teller']==df['Pay Teller']) & df['Date of Purchase']==df['Date of Encashment'] & df['Issue Branch Code']!=df['Pay Branch Code']
# Out:
# 4663100000.0

# %% [markdown]
# # Visualisations for not accounted money

# %% [markdown]
# Observations
# * All the donations recieved by AIADMK is unaccounted for
# *

# %%
# df[(df['Name of the Purchaser'].isnull())][['Name of the Political Party','Denominations']].groupby('Name of the Political Party').sum().sort_values(by='Denominations', ascending=False)
nan_ = df[(df['Name of the Purchaser'].isnull())]
t_ = nan_[['Name of the Political Party', 'Denominations']].groupby('Name of the Political Party').sum().sort_values(by='Denominations', ascending=False).rename(columns={'Denominations':'Not accounted'})
t_['Total Denominations'] = denom_['Denominations']
t_['%Not accounted denom of total denominations']=100*t_['Not accounted']/t_['Total Denominations']
nan_=nan_.sort_values(by ='Date of Encashment')
t_
# Out:
#                                                     Not accounted  \
# Name of the Political Party
# BHARATIYA JANATA PARTY                               4.663100e+09
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE              7.077100e+08
# BHARAT RASHTRA SAMITHI                               2.355000e+08
# ALL INDIA TRINAMOOL CONGRESS                         1.701000e+08
# YSR CONGRESS PARTY (YUVAJANA SRAMIKA RYTHU CONG...   8.250000e+07
# TELUGU DESAM PARTY                                   7.300000e+07
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                      7.000000e+07
# SHIVSENA                                             6.930000e+07
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM             6.050000e+07
# JANATA DAL ( SECULAR )                               2.500000e+07
# NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH       2.500000e+07
# BIHAR PRADESH JANTA DAL(UNITED)                      2.000000e+07
# JHARKHAND MUKTI MORCHA                               1.000000e+07
# RASHTRIYA JANTA DAL                                  1.000000e+07
# ADYAKSHA SAMAJVADI PARTY                             8.400000e+06
# AAM AADMI PARTY                                      2.000000e+06
#
#                                                     Total Denominations  \
# Name of the Political Party
# BHARATIYA JANATA PARTY                                     6.060511e+10
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE                    1.421866e+10
# BHARAT RASHTRA SAMITHI                                     1.214710e+10
# ALL INDIA TRINAMOOL CONGRESS                               1.609531e+10
# YSR CONGRESS PARTY (YUVAJANA SRAMIKA RYTHU CONG...         3.370000e+09
# TELUGU DESAM PARTY                                         2.188800e+09
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                            6.390000e+09
# SHIVSENA                                                   1.593814e+09
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                   6.050000e+07
# JANATA DAL ( SECULAR )                                     4.350000e+08
# NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH             3.100000e+08
# BIHAR PRADESH JANTA DAL(UNITED)                            1.400000e+08
# JHARKHAND MUKTI MORCHA                                     1.350000e+08
# RASHTRIYA JANTA DAL                                        7.350000e+08
# ADYAKSHA SAMAJVADI PARTY                                   1.405000e+08
# AAM AADMI PARTY                                            6.545000e+08
#
#                                                     %Not accounted denom of total denominations
# Name of the Political Party
# BHARATIYA JANATA PARTY                                                                 7.694236
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE                                                4.977334
# BHARAT RASHTRA SAMITHI                                                                 1.938735
# ALL INDIA TRINAMOOL CONGRESS                                                           1.056829
# YSR CONGRESS PARTY (YUVAJANA SRAMIKA RYTHU CONG...                                     2.448071
# TELUGU DESAM PARTY                                                                     3.335161
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                                        1.095462
# SHIVSENA                                                                               4.348061
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                                             100.000000
# JANATA DAL ( SECULAR )                                                                 5.747126
# NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH                                         8.064516
# BIHAR PRADESH JANTA DAL(UNITED)                                                       14.285714
# JHARKHAND MUKTI MORCHA                                                                 7.407407
# RASHTRIYA JANTA DAL                                                                    1.360544
# ADYAKSHA SAMAJVADI PARTY                                                               5.978648
# AAM AADMI PARTY                                                                        0.305577

# %%
date_range_slider = pn.widgets.DateRangeSlider(
    name='Date Range Slider',
    start=dt.datetime(2017, 1, 1), end=dt.datetime(2019, 1, 1),
    # value=(dt.datetime(2017, 1, 1), dt.datetime(2018, 1, 10)),
    step=2
)



date_range_slider
def plot():
    fig=plt.figure()
    ax=fig.add_subplot()
    ax.pie(t_['Not accounted'], labels = t_.index, autopct='%1.2f%%')
    return fig
    
mpl = pn.pane.Matplotlib(
    pn.bind(plot)
)

pn.Column(mpl).servable(target='main')

pn.Row(date_range_slider.controls(), date_range_slider)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 17
#      14     ax.pie(t_['Not accounted'], labels = t_.index, autopct='%1.2f%%')
#      15     return fig
# ---> 17 mpl = pn.panel.Matplotlib(
#      18     pn.bind(plot)
#      19 )
#      21 pn.Column(mpl).servable(target='main')
#      23 pn.Row(date_range_slider.controls(), date_range_slider)
#
# AttributeError: 'function' object has no attribute 'Matplotlib'

# %%
fig,ax=plt.subplots()
ax.pie(t_['Not accounted'], labels = t_.index, autopct='%1.2f%%')
plt.show()

# %%
party = 'BHARATIYA JANATA PARTY'

sns.set_theme(style='ticks')
f, ax= plt.subplots()
sns.despine(f)

sns.histplot(
    nan_[['Date of Encashment', 'Name of the Political Party', 'Denominations']].sort_values(by=['Date of Encashment', 'Denominations'], ascending=[True, False]),
    x='Date of Encashment',
    hue='Name of the Political Party',
    multiple='stack',
    edgecolor=".3",
    linewidth=.5
)

sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xticks(rotation='vertical')
plt.show()

# %%
nan_[['Date of Encashment', 'Name of the Political Party', 'Denominations']].groupby(by=['Date of Encashment', 'Name of the Political Party']).sum().sort_values(by=['Date of Encashment','Denominations'], ascending=[True,False])
# Out:
#                                                                        Denominations
# Date of Encashment Name of the Political Party
# 2019-04-12         BHARATIYA JANATA PARTY                               2.463000e+09
#                    BHARAT RASHTRA SAMITHI                               2.250000e+08
#                    PRESIDENT, ALL INDIA CONGRESS COMMITTEE              1.010000e+08
#                    YSR CONGRESS PARTY (YUVAJANA SRAMIKA RYTHU CONG...   6.250000e+07
#                    ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM             6.000000e+07
#                    SHIVSENA                                             3.700000e+07
#                    TELUGU DESAM PARTY                                   3.000000e+06
# 2019-04-15         BHARATIYA JANATA PARTY                               5.005000e+08
#                    PRESIDENT, ALL INDIA CONGRESS COMMITTEE              3.545000e+08
#                    DRAVIDA MUNNETRA KAZHAGAM (DMK)                      7.000000e+07
#                    TELUGU DESAM PARTY                                   5.000000e+07
#                    JANATA DAL ( SECULAR )                               2.500000e+07
#                    SHIVSENA                                             2.000000e+07
#                    NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH       1.500000e+07
#                    ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM             5.000000e+05
# 2019-04-16         BHARATIYA JANATA PARTY                               7.120000e+08
#                    PRESIDENT, ALL INDIA CONGRESS COMMITTEE              1.792000e+08
#                    ALL INDIA TRINAMOOL CONGRESS                         1.701000e+08
#                    BIHAR PRADESH JANTA DAL(UNITED)                      2.000000e+07
#                    RASHTRIYA JANTA DAL                                  1.000000e+07
# 2019-04-18         BHARATIYA JANATA PARTY                               5.823000e+08
#                    PRESIDENT, ALL INDIA CONGRESS COMMITTEE              5.180000e+07
#                    TELUGU DESAM PARTY                                   2.000000e+07
#                    YSR CONGRESS PARTY (YUVAJANA SRAMIKA RYTHU CONG...   2.000000e+07
#                    BHARAT RASHTRA SAMITHI                               1.000000e+07
#                    NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH       1.000000e+07
#                    ADYAKSHA SAMAJVADI PARTY                             8.400000e+06
#                    AAM AADMI PARTY                                      2.000000e+06
#                    SHIVSENA                                             2.000000e+06
# 2019-04-20         BHARATIYA JANATA PARTY                               2.820000e+08
#                    PRESIDENT, ALL INDIA CONGRESS COMMITTEE              1.021000e+07
# 2019-04-22         BHARATIYA JANATA PARTY                               2.780000e+07
#                    PRESIDENT, ALL INDIA CONGRESS COMMITTEE              1.000000e+07
#                    BHARAT RASHTRA SAMITHI                               5.000000e+05
# 2019-04-23         BHARATIYA JANATA PARTY                               4.500000e+07
#                    JHARKHAND MUKTI MORCHA                               1.000000e+07
#                    SHIVSENA                                             1.000000e+07
# 2019-04-24         PRESIDENT, ALL INDIA CONGRESS COMMITTEE              1.000000e+06
# 2019-04-25         BHARATIYA JANATA PARTY                               5.050000e+07
#                    SHIVSENA                                             3.000000e+05

# %%
# pn.extension(template='fast')

# freq = pn.widgets.FloatSlider(
#     name='Frequency', start=0, end=10, value=5
# ).servable(target='sidebar')

# ampl = pn.widgets.FloatSlider(
#     name='Amplitude', start=0, end=1, value=0.5
# ).servable(target='sidebar')

# def plot(freq, ampl):
#     fig = plt.figure()
#     ax = fig.add_subplot(111)
#     xs = np.linspace(0, 1)
#     ys = np.sin(xs*freq)*ampl
#     ax.plot(xs, ys)
#     return fig

# mpl = pn.pane.Matplotlib(
#     pn.bind(plot, freq, ampl)
# )

# pn.Column(
#     '# Sine curve', mpl
# ).servable(target='main')
